# %%
import pandas as pd
import numpy as np

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

print("Libraries Imported Successfully!")
# Out:
# Libraries Imported Successfully!

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Anusha Vootla\OneDrive\Desktop\Netflix-Content-Analysis\notebooks

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '02_Data_Cleaning.ipynb', 'netflix_analysis.ipynb']

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Anusha Vootla\OneDrive\Desktop\Netflix-Content-Analysis\data\raw\netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
netflix = df.copy()

# %%
netflix["country"].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
netflix["country"].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Anusha Vootla\OneDrive\Desktop\Netflix-Content-Analysis\notebooks

# %%
import os

print(os.listdir("data"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 import os
# ----> 3 print(os.listdir("data"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data'

# %%
import os

print(os.path.exists("data/cleaned"))
# Out:
# False

# %%
import os

os.makedirs("data/cleaned", exist_ok=True)

# %%
netflix.to_csv("data/cleaned/netflix_cleaned.csv", index=False)

# %%
netflix.to_csv(
    r"C:\Users\Anusha Vootla\OneDrive\Desktop\Netflix-Content-Analysis\data\cleaned\netflix_cleaned.csv",
    index=False
)

# %%
import os

print("Current Folder:", os.getcwd())
print("Data Folder:", os.listdir("data"))
print("Cleaned Exists:", os.path.exists("data/cleaned"))
# Out:
# Current Folder: C:\Users\Anusha Vootla\OneDrive\Desktop\Netflix-Content-Analysis\notebooks
# Data Folder: ['cleaned']
# Cleaned Exists: True

# %%
netflix.to_csv("../data/cleaned/netflix_cleaned.csv", index=False)

# %%
netflix["country"].head(10)
# Out:
# 0                                        United States
# 1                                         South Africa
# 2                                                  NaN
# 3                                                  NaN
# 4                                                India
# 5                                                  NaN
# 6                                                  NaN
# 7    United States, Ghana, Burkina Faso, United Kin...
# 8                                       United Kingdom
# 9                                        United States
# Name: country, dtype: object
